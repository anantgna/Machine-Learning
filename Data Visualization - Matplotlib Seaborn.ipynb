# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
boston_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/boston_train.csv', sep = ',')

# %%
boston_df
# Out:
#          CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO  MEDV
# 0     2.30040   0.0  19.58  0.605  6.319  96.1  2.1000  403     14.7  23.8
# 1    13.35980   0.0  18.10  0.693  5.887  94.7  1.7821  666     20.2  12.7
# 2     0.12744   0.0   6.91  0.448  6.770   2.9  5.7209  233     17.9  26.6
# 3     0.15876   0.0  10.81  0.413  5.961  17.5  5.2873  305     19.2  21.7
# 4     0.03768  80.0   1.52  0.404  7.274  38.3  7.3090  329     12.6  34.6
# ..        ...   ...    ...    ...    ...   ...     ...  ...      ...   ...
# 395   0.23912   0.0   9.69  0.585  6.019  65.3  2.4091  391     19.2  21.2
# 396   0.04560   0.0  13.89  0.550  5.888  56.0  3.1121  276     16.4  23.3
# 397   1.38799   0.0   8.14  0.538  5.950  82.0  3.9900  307     21.0  13.2
# 398   7.36711   0.0  18.10  0.679  6.193  78.1  1.9356  666     20.2  11.0
# 399   0.14150   0.0   6.91  0.448  6.169   6.6  5.7209  233     17.9  25.3
#
# [400 rows x 10 columns]

# %%
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# TAX        0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %% [markdown]
# **Line Plot**

# %%
plt.figure(figsize=(20,9))
plt.plot(boston_df['AGE'])
plt.title("Line Plot")
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %%
plt.figure(figsize=(12,9))
plt.plot(boston_df['AGE'].sort_values(ascending=True).unique(),color='cyan')
plt.title("Line Plot",fontsize = 14)
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# **Bar Graph**
#
# *   Frequency with a discrete category

# %%
plt.figure(figsize=(12,9))
plt.bar(x = boston_df['ZN'],height=boston_df['AGE'],width=1.5,color='cyan')
plt.title("Bar Plot",fontsize = 14)
plt.xlabel("ZN")
plt.ylabel("AGE")
plt.show()

# %%
 '''[1,2,,4,10,12,15,17,21,23,25,29,31,32,37,38,41,42,44,51,52,61]
(1-10) - 4
(11-20) - 3
(21-30) - 4
(31-40) - 4
(41-50) - 3
(51-60) - 2'''
# Out:
# '[1,2,,4,10,12,15,17,21,23,25,29,31,32,37,38,41,42,44,51,52,61]\n(1-10) - 4\n(11-20) - 3\n(21-30) - 4\n(31-40) - 4\n(41-50) - 3\n(51-60) - 2'

# %% [markdown]
# **Histogram Plot**
#
# *   Continous Data Representation (Range vs Frequency of Data)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(15,10))
plt.hist(boston_df['MEDV'], bins = 20,color='cyan')
plt.title("Historgram Plot",fontsize = 14)
plt.xlabel("Range of MEDV")
plt.ylabel("Frequency (in Range)")
plt.show()

# %% [markdown]
# **Scatter Plot**
#
# *   Relationship Plot b/w X & Y

# %%
iris_df = pd.read_csv("https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/iris.csv" , sep =',')

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(15,10))
plt.scatter(x = iris_df['sepal_length'], y = iris_df['sepal_width'], marker ='^', color = 'magenta')
plt.scatter(x = iris_df['sepal_length'], y = iris_df['petal_width'],  marker ='^', color = 'blue')
plt.title("Scatter Plot",fontsize = 14)
plt.xlabel("Sepal Length", fontsize = 15)
plt.ylabel("Sepal/Petal Length", fontsize = 15)
plt.legend( loc = 4)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# **Scatter Plot Using Seaborn**

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', data = iris_df, hue = 'species', marker = 's')
plt.plot()
# Out:
# []

# %% [markdown]
# **Pie Chart**

# %%
slices = [7, 3, 6, 4, 2, 2]
day_activites = ['sleeping', 'eating', 'coding', 'playing','reading','others']

plt.figure(figsize=(10,10))
plt.pie(slices, labels=day_activites, autopct='%1.1f%%', explode = (0,0,0,0,0,0,))
plt.show()

# %% [markdown]
# **Displaying Image Using Matplotlib**

# %%
#import matplotlib.image as mpimg

# %%
#img = mpimg.imread('/content/2.png')

# %%
#plt.imshow(img)

# %% [markdown]
# **Relationship Graph**

# %%
plt.figure(figsize=(15,8))
sns.distplot(boston_df['MEDV'], color = 'orangered')

# %%
plt.figure(figsize=(15,8))

sns.boxplot(data = iris_df,orient='h',palette = 'icefire')
plt.show()

# %%
# Median of AGE

boston_df['AGE'].median()
# Out:
# 78.80000000000001

# %%
# Mode of AGE

boston_df['AGE'].mode()
# Out:
# 0    100.0
# dtype: float64

# %%
# Mean of AGE

boston_df['AGE'].mean()
# Out:
# 69.11399999999998

# %% [markdown]
# **Correlation Plot**

# %%
boston_df.corr()
# Out:
#              CRIM        ZN     INDUS  ...       TAX   PTRATIO      MEDV
# CRIM     1.000000 -0.197764  0.383433  ...  0.563791  0.284306 -0.375836
# ZN      -0.197764  1.000000 -0.532929  ... -0.323539 -0.393904  0.365931
# INDUS    0.383433 -0.532929  1.000000  ...  0.722435  0.386248 -0.465083
# NOX      0.407698 -0.521745  0.758157  ...  0.664923  0.185284 -0.410425
# RM      -0.219043  0.328418 -0.393738  ... -0.302268 -0.395436  0.685041
# AGE      0.350003 -0.561062  0.644559  ...  0.521723  0.260205 -0.368922
# DIS     -0.377643  0.665677 -0.717796  ... -0.555040 -0.227288  0.236714
# TAX      0.563791 -0.323539  0.722435  ...  1.000000  0.473023 -0.449570
# PTRATIO  0.284306 -0.393904  0.386248  ...  0.473023  1.000000 -0.531764
# MEDV    -0.375836  0.365931 -0.465083  ... -0.449570 -0.531764  1.000000
#
# [10 rows x 10 columns]

# %%
plt.figure(figsize = (12 ,8))
sns.heatmap(boston_df.corr(), annot = True, cmap='cool')

# %%
titanic_df = pd.read_csv("https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/Titanic_Data.csv")

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(titanic_df.isnull(), yticklabels = False, xticklabels = False)

# %% [markdown]
# **Catplot**

# %%
#plt.figure(figsize=(100,100))
sns.catplot(x = 'Sex', data = titanic_df, kind = 'count', palette='magma')

# %%
sns.catplot( x = 'Sex', hue = 'Survived', data = titanic_df, kind = 'count', palette='magma')

# %%
sns.catplot( x = 'Pclass', hue = 'Survived', data = titanic_df, kind = 'count', palette='magma')

# %% [markdown]
# **Subplotting**

# %%
fig = plt.figure(figsize=(20,8))

# add subplot (1, 3, 1)(1 = Row, 3 = Column, 1 = position of image) 

ax = fig.add_subplot(1, 3, 1) 
sns.distplot(iris_df['sepal_length'], color ='c')
ax.set_title('Distribution  of Sepal Length')

ax = fig.add_subplot(1, 3, 2)
sns.distplot(iris_df['petal_length'], color ='m')
ax.set_title('Distribution  of Petal Length')

ax = fig.add_subplot(1, 3, 3)
sns.distplot(iris_df['petal_width'], color ='b')
ax.set_title('Distribution  of Petal Width')
# Out:
# Text(0.5, 1.0, 'Distribution  of Petal Width')

# %% [markdown]
# **KDE(Kernal Density Estimator) Plot**

# %%
iris_setosa = iris_df.query("species == 'setosa'")
iris_virginica = iris_df.query("species == 'virginica'")

# %%
sns.kdeplot(iris_setosa['sepal_length'], shade = True, Label = 'setosa', color = 'red')
sns.kdeplot(iris_virginica['sepal_length'], shade = True, Label = 'virginica', color = 'blue')

# %%
sns.set_style('ticks')
sns.kdeplot(iris_setosa['sepal_length'], iris_setosa['sepal_width'], shade=True, Label ="Setosa", cmap = 'PuRd', shade_lowest = False)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:434: UserWarning: The following kwargs were not used by contour: 'Label'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)

# %% [markdown]
# **3-D Plot**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection = '3d')

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection = '3d')

# Data for three dimensional

zpoints = np.linspace(0, 15, 1000)
xpoints = np.sin(zpoints)
ypoints = np.cos(zpoints)

ax.plot3D(xpoints, ypoints, zpoints, 'red')

ax.set_title("Line Plot")

plt.show()

# %%
def fun(x, y):
  return np.tan(np.sqrt(x**2 + y**2))

# %%
x = np.linspace(-5, 5, 30)
y = np.linspace(-5, 5, 30)

X , Y = np.meshgrid(x, y)
Z = fun(X, Y)

# %%
plt.figure(figsize=(20,8))
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.contour3D(X, Y, Z, 50, cmap='Dark2')

plt.show()

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
boston_df
# Out:
#          CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO  MEDV
# 0     2.30040   0.0  19.58  0.605  6.319  96.1  2.1000  403     14.7  23.8
# 1    13.35980   0.0  18.10  0.693  5.887  94.7  1.7821  666     20.2  12.7
# 2     0.12744   0.0   6.91  0.448  6.770   2.9  5.7209  233     17.9  26.6
# 3     0.15876   0.0  10.81  0.413  5.961  17.5  5.2873  305     19.2  21.7
# 4     0.03768  80.0   1.52  0.404  7.274  38.3  7.3090  329     12.6  34.6
# ..        ...   ...    ...    ...    ...   ...     ...  ...      ...   ...
# 395   0.23912   0.0   9.69  0.585  6.019  65.3  2.4091  391     19.2  21.2
# 396   0.04560   0.0  13.89  0.550  5.888  56.0  3.1121  276     16.4  23.3
# 397   1.38799   0.0   8.14  0.538  5.950  82.0  3.9900  307     21.0  13.2
# 398   7.36711   0.0  18.10  0.679  6.193  78.1  1.9356  666     20.2  11.0
# 399   0.14150   0.0   6.91  0.448  6.169   6.6  5.7209  233     17.9  25.3
#
# [400 rows x 10 columns]

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x = boston_df['MEDV'], y = boston_df['AGE'], data = iris_df, marker = 's')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x = boston_df['MEDV'], y = boston_df['RM'], data = iris_df, marker = 's')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x = boston_df['MEDV'], y = boston_df['DIS'], data = iris_df, marker = 's')
plt.plot()
# Out:
# []

# %%
fig = plt.figure(figsize = (12, 8))

ax = fig.add_subplot(1, 3, 1)
sns.scatterplot(x = boston_df['MEDV'], y =boston_df['RM'])

ax = fig.add_subplot(1, 3, 2)
sns.scatterplot(x = boston_df['MEDV'], y =boston_df['DIS'])

ax = fig.add_subplot(1, 3, 3)
sns.scatterplot(x = boston_df['MEDV'], y =boston_df['AGE'])
