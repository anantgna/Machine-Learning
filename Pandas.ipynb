# %%
import pandas as pd

#1 - D Data Representation
data_series=pd.Series(data = [100, 200, 300, 400, 500, 600, 700], index=['a','b','c','d','e','f','g'])

# %%
display(data_series)

# %%
print(data_series)

# %%
data_series.values
# Out:
# array([100, 200, 300, 400, 500, 600, 700])

# %%
data_series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
data_series = {'column 1' :pd.Series(data = [100,200,300,400,500,], index=['a', 'b', 'c', 'd', 'e']),
               'column 2' :pd.Series(data = [10,20,30,40,50,], index=['a', 'b', 'c', 'd', 'e'])}

# %%
display(data_series)
# Out:
# {'column 1': a    100
#  b    200
#  c    300
#  d    400
#  e    500
#  dtype: int64, 'column 2': a    10
#  b    20
#  c    30
#  d    40
#  e    50
#  dtype: int64}

# %%
sales = {'CustomerId' : [1001, 1002, 1003, 1004, 1005, 1006],
         'ProductId' : ['x1001', 'x1002', 'x1003', 'x1004', 'x1005', 'x1006'],
         'Price' : [999, 1999, 2999, 3999, 4999, 5999]}

# %%
pd.DataFrame(sales)

# %%
movies_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/movies.csv', sep = ',')

# %%
movies_df
# Out:
#                                   Film    Genre  ... Worldwide Gross  Year
# 0           Zack and Miri Make a Porno  Romance  ...         $41.94   2008
# 1                      Youth in Revolt   Comedy  ...         $19.62   2010
# 2   You Will Meet a Tall Dark Stranger   Comedy  ...         $26.66   2010
# 3                         When in Rome   Comedy  ...         $43.04   2010
# 4                What Happens in Vegas   Comedy  ...        $219.37   2008
# ..                                 ...      ...  ...             ...   ...
# 72                 Across the Universe  romance  ...         $29.37   2007
# 73                       A Serious Man    Drama  ...         $30.68   2009
# 74                  A Dangerous Method    Drama  ...          $8.97   2011
# 75                          27 Dresses   Comedy  ...        $160.31   2008
# 76                (500) Days of Summer   comedy  ...         $60.72   2009
#
# [77 rows x 8 columns]

# %%
movies_df.head(10)
# Out:
#                                  Film      Genre  ... Worldwide Gross  Year
# 0          Zack and Miri Make a Porno    Romance  ...         $41.94   2008
# 1                     Youth in Revolt     Comedy  ...         $19.62   2010
# 2  You Will Meet a Tall Dark Stranger     Comedy  ...         $26.66   2010
# 3                        When in Rome     Comedy  ...         $43.04   2010
# 4               What Happens in Vegas     Comedy  ...        $219.37   2008
# 5                 Water For Elephants      Drama  ...        $117.09   2011
# 6                              WALL-E  Animation  ...        $521.28   2008
# 7                            Waitress    Romance  ...         $22.18   2007
# 8                 Waiting For Forever    Romance  ...          $0.03   2011
# 9                     Valentine's Day     Comedy  ...        $217.57   2010
#
# [10 rows x 8 columns]

# %%
movies_df.tail()
# Out:
#                     Film    Genre  ... Worldwide Gross  Year
# 72   Across the Universe  romance  ...         $29.37   2007
# 73         A Serious Man    Drama  ...         $30.68   2009
# 74    A Dangerous Method    Drama  ...          $8.97   2011
# 75            27 Dresses   Comedy  ...        $160.31   2008
# 76  (500) Days of Summer   comedy  ...         $60.72   2009
#
# [5 rows x 8 columns]

# %%
stock_data= pd.read_excel('https://github.com/ammishra08/MachineLearning/blob/master/Datasets/data_akbilgic.xlsx?raw=true',header =1)

# %%
stock_data
# Out:
#           date       ISE     ISE.1  ...   BOVESPA        EU        EM
# 0   2009-01-05  0.035754  0.038376  ...  0.031190  0.012698  0.028524
# 1   2009-01-06  0.025426  0.031813  ...  0.018920  0.011341  0.008773
# 2   2009-01-07 -0.028862 -0.026353  ... -0.035899 -0.017073 -0.020015
# 3   2009-01-08 -0.062208 -0.084716  ...  0.028283 -0.005561 -0.019424
# 4   2009-01-09  0.009860  0.009658  ... -0.009764 -0.010989 -0.007802
# ..         ...       ...       ...  ...       ...       ...       ...
# 531 2011-02-16  0.008599  0.013400  ...  0.018371  0.006975  0.003039
# 532 2011-02-17  0.009310  0.015977  ...  0.001686 -0.000581  0.001039
# 533 2011-02-18  0.000191 -0.001653  ...  0.005628  0.000572  0.006938
# 534 2011-02-21 -0.013069 -0.013706  ... -0.011942 -0.012615 -0.000958
# 535 2011-02-22 -0.007246 -0.019442  ... -0.012252 -0.005465 -0.014297
#
# [536 rows x 10 columns]

# %%
stock_data.head()
# Out:
#         date       ISE     ISE.1  ...   BOVESPA        EU        EM
# 0 2009-01-05  0.035754  0.038376  ...  0.031190  0.012698  0.028524
# 1 2009-01-06  0.025426  0.031813  ...  0.018920  0.011341  0.008773
# 2 2009-01-07 -0.028862 -0.026353  ... -0.035899 -0.017073 -0.020015
# 3 2009-01-08 -0.062208 -0.084716  ...  0.028283 -0.005561 -0.019424
# 4 2009-01-09  0.009860  0.009658  ... -0.009764 -0.010989 -0.007802
#
# [5 rows x 10 columns]

# %%
#isnull() will return True or false for missing values[Nan]
movies_df.isnull()
# Out:
#      Film  Genre  Lead Studio  ...  Rotten Tomatoes %  Worldwide Gross   Year
# 0   False  False        False  ...              False            False  False
# 1   False  False        False  ...              False            False  False
# 2   False  False        False  ...              False            False  False
# 3   False  False        False  ...              False            False  False
# 4   False  False        False  ...              False            False  False
# ..    ...    ...          ...  ...                ...              ...    ...
# 72  False  False        False  ...              False            False  False
# 73  False  False        False  ...              False            False  False
# 74  False  False        False  ...              False            False  False
# 75  False  False        False  ...              False            False  False
# 76  False  False        False  ...              False            False  False
#
# [77 rows x 8 columns]

# %%
movies_df.isnull().sum()
# Out:
# Film                 0
# Genre                0
# Lead Studio          0
# Audience score %     0
# Profitability        0
# Rotten Tomatoes %    0
# Worldwide Gross      0
# Year                 0
# dtype: int64

# %%
#Selecting Columns
X = movies_df[['Film','Year','Worldwide Gross']]
X  #2 square brackets because it is multi dimensional
# Out:
#                                   Film  Year Worldwide Gross
# 0           Zack and Miri Make a Porno  2008         $41.94
# 1                      Youth in Revolt  2010         $19.62
# 2   You Will Meet a Tall Dark Stranger  2010         $26.66
# 3                         When in Rome  2010         $43.04
# 4                What Happens in Vegas  2008        $219.37
# ..                                 ...   ...             ...
# 72                 Across the Universe  2007         $29.37
# 73                       A Serious Man  2009         $30.68
# 74                  A Dangerous Method  2011          $8.97
# 75                          27 Dresses  2008        $160.31
# 76                (500) Days of Summer  2009         $60.72
#
# [77 rows x 3 columns]

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
movies_df['Genre'].unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
movies_df['Audience score %'].unique()
# Out:
# array([70, 52, 35, 44, 72, 89, 67, 53, 54, 47, 68, 82, 78, 65, 74, 41, 81,
#        88, 48, 60, 49, 61, 66, 64, 84, 50, 77, 76, 40, 55, 62, 83, 45, 58,
#        63, 57, 56, 51, 80, 71])

# %%
#column index = score
movies_df.filter(like='score')
# Out:
#     Audience score %
# 0                 70
# 1                 52
# 2                 35
# 3                 44
# 4                 72
# ..               ...
# 72                84
# 73                64
# 74                89
# 75                71
# 76                81
#
# [77 rows x 1 columns]

# %%
movies_df.filter(like='Year').sort_values(by= 'Year')
# Out:
#     Year
# 51  2007
# 31  2007
# 40  2007
# 18  2007
# 54  2007
# ..   ...
# 43  2011
# 41  2011
# 39  2011
# 65  2011
# 38  2011
#
# [77 rows x 1 columns]

# %%
stock_data.groupby('date')

# %%
#Before ',' its for all the rows and after ',' its for all columns
movies_df.loc[:, ['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability']]
# Out:
#                                   Film  ... Profitability
# 0           Zack and Miri Make a Porno  ...      1.747542
# 1                      Youth in Revolt  ...      1.090000
# 2   You Will Meet a Tall Dark Stranger  ...      1.211818
# 3                         When in Rome  ...      0.000000
# 4                What Happens in Vegas  ...      6.267647
# ..                                 ...  ...           ...
# 72                 Across the Universe  ...      0.652603
# 73                       A Serious Man  ...      4.382857
# 74                  A Dangerous Method  ...      0.448645
# 75                          27 Dresses  ...      5.343622
# 76                (500) Days of Summer  ...      8.096000
#
# [77 rows x 5 columns]

# %%
movies_df.loc[:,:]
# Out:
#                                   Film    Genre  ... Worldwide Gross  Year
# 0           Zack and Miri Make a Porno  Romance  ...         $41.94   2008
# 1                      Youth in Revolt   Comedy  ...         $19.62   2010
# 2   You Will Meet a Tall Dark Stranger   Comedy  ...         $26.66   2010
# 3                         When in Rome   Comedy  ...         $43.04   2010
# 4                What Happens in Vegas   Comedy  ...        $219.37   2008
# ..                                 ...      ...  ...             ...   ...
# 72                 Across the Universe  romance  ...         $29.37   2007
# 73                       A Serious Man    Drama  ...         $30.68   2009
# 74                  A Dangerous Method    Drama  ...          $8.97   2011
# 75                          27 Dresses   Comedy  ...        $160.31   2008
# 76                (500) Days of Summer   comedy  ...         $60.72   2009
#
# [77 rows x 8 columns]

# %%
movies_df.loc[10:40,['Film', 'Genre', 'Audience score %', 'Profitability']]
# Out:
#                                    Film  ... Profitability
# 10  Tyler Perry's Why Did I get Married  ...      3.724192
# 11              Twilight: Breaking Dawn  ...      6.383364
# 12                             Twilight  ...     10.180027
# 13                       The Ugly Truth  ...      5.402632
# 14          The Twilight Saga: New Moon  ...     14.196400
# 15             The Time Traveler's Wife  ...      2.598205
# 16                         The Proposal  ...      7.867500
# 17               The Invention of Lying  ...      1.751351
# 18                   The Heartbreak Kid  ...      2.129444
# 19                          The Duchess  ...      3.207850
# 20  The Curious Case of Benjamin Button  ...      1.783944
# 21                     The Back-up Plan  ...      2.202571
# 22                              Tangled  ...      1.365692
# 23                   Something Borrowed  ...      1.719514
# 24               She's Out of My League  ...      2.440500
# ...

# %%
#in iloc, i stands for index. .iloc is used for entire rows
movies_df.iloc[ 10:-2, :]
# Out:
#                                    Film    Genre  ... Worldwide Gross  Year
# 10  Tyler Perry's Why Did I get Married  Romance  ...         $55.86   2007
# 11              Twilight: Breaking Dawn  Romance  ...        $702.17   2011
# 12                             Twilight  Romance  ...        $376.66   2008
# 13                       The Ugly Truth   Comedy  ...        $205.30   2009
# 14          The Twilight Saga: New Moon    Drama  ...        $709.82   2009
# ..                                  ...      ...  ...             ...   ...
# 70                            Dear John    Drama  ...        $114.97   2010
# 71                            Beginners   Comedy  ...         $14.31   2011
# 72                  Across the Universe  romance  ...         $29.37   2007
# 73                        A Serious Man    Drama  ...         $30.68   2009
# 74                   A Dangerous Method    Drama  ...          $8.97   2011
#
# [65 rows x 8 columns]

# %%
movies_df.iloc[ 10:20, 0:4]
# Out:
#                                    Film  ... Audience score %
# 10  Tyler Perry's Why Did I get Married  ...               47
# 11              Twilight: Breaking Dawn  ...               68
# 12                             Twilight  ...               82
# 13                       The Ugly Truth  ...               68
# 14          The Twilight Saga: New Moon  ...               78
# 15             The Time Traveler's Wife  ...               65
# 16                         The Proposal  ...               74
# 17               The Invention of Lying  ...               47
# 18                   The Heartbreak Kid  ...               41
# 19                          The Duchess  ...               68
#
# [10 rows x 4 columns]

# %%
# Set new index values using column Film
movie_new= movies_df.set_index('Film')
movie_new
# Out:
#                                       Genre  ...  Year
# Film                                         ...
# Zack and Miri Make a Porno          Romance  ...  2008
# Youth in Revolt                      Comedy  ...  2010
# You Will Meet a Tall Dark Stranger   Comedy  ...  2010
# When in Rome                         Comedy  ...  2010
# What Happens in Vegas                Comedy  ...  2008
# ...                                     ...  ...   ...
# Across the Universe                 romance  ...  2007
# A Serious Man                         Drama  ...  2009
# A Dangerous Method                    Drama  ...  2011
# 27 Dresses                           Comedy  ...  2008
# (500) Days of Summer                 comedy  ...  2009
#
# [77 rows x 7 columns]

# %%
movie_new.loc['What Happens in Vegas']
# Out:
# Genre                  Comedy
# Lead Studio               Fox
# Audience score %           72
# Profitability         6.26765
# Rotten Tomatoes %          28
# Worldwide Gross      $219.37
# Year                     2008
# Name: What Happens in Vegas, dtype: object

# %%
movie_new.iloc[10]
# Out:
# Genre                    Romance
# Lead Studio          Independent
# Audience score %              47
# Profitability            3.72419
# Rotten Tomatoes %             46
# Worldwide Gross          $55.86
# Year                        2007
# Name: Tyler Perry's Why Did I get Married, dtype: object

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     536 non-null    datetime64[ns]
#  1   ISE      536 non-null    float64
#  2   ISE.1    536 non-null    float64
#  3   SP       536 non-null    float64
#  4   DAX      536 non-null    float64
#  5   FTSE     536 non-null    float64
#  6   NIKKEI   536 non-null    float64
#  7   BOVESPA  536 non-null    float64
#  8   EU       536 non-null    float64
#  9   EM       536 non-null    float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 42.0 KB

# %%
stock_data['ISE'].plot(figsize = (20,10))

# %%
stock_data.loc[200:400, 'EU'].plot(figsize = (20,10), title = 'Line Plot', color = 'orangered')

# %%
movies_df['Audience score %'].plot(kind = 'bar', figsize = (20,10), title = 'Bar Plot')
