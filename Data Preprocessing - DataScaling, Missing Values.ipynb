# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
diabetes = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/diabetes.csv')

# %%
#diabetes

# %% [markdown]
# **Missing Values**

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
diabetes_df = diabetes[['Glucose', 'BloodPressure', 'SkinThickness',	'Insulin',	'BMI',	'DiabetesPedigreeFunction',	'Age'	]].replace(0, np.nan)

# %%
#ADD NEW COLUMN TO THE EXISTING DATAFRAME

diabetes_df['Pregnancies'] = diabetes['Pregnancies']

# %%
diabetes_df['Outcome'] = diabetes['Outcome']

# %%
diabetes_df
# Out:
#      Glucose  BloodPressure  SkinThickness  ...  Age  Pregnancies  Outcome
# 0      148.0           72.0           35.0  ...   50            6        1
# 1       85.0           66.0           29.0  ...   31            1        0
# 2      183.0           64.0            NaN  ...   32            8        1
# 3       89.0           66.0           23.0  ...   21            1        0
# 4      137.0           40.0           35.0  ...   33            0        1
# ..       ...            ...            ...  ...  ...          ...      ...
# 763    101.0           76.0           48.0  ...   63           10        0
# 764    122.0           70.0           27.0  ...   27            2        0
# 765    121.0           72.0           23.0  ...   30            5        0
# 766    126.0           60.0            NaN  ...   47            1        1
# 767     93.0           70.0           31.0  ...   23            1        0
#
# [768 rows x 9 columns]

# %%
diabetes_df.isnull().sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Pregnancies                   0
# Outcome                       0
# dtype: int64

# %% [markdown]
# **Missing Values by Replace**

# %%
# Mean = when Missing data is continious
# Median = When Missing data is discrete
# Mode = When Missung data is discrete

# %%
diabetes_df['Insulin'].unique()
# Out:
# array([156.,  94., 168.,  88., 543., 846., 175., 230.,  83.,  96., 235.,
#        146., 115., 140., 110., 245.,  54., 192., 207.,  70., 240.,  82.,
#         36.,  23., 300., 342., 304., 142., 128.,  38., 100.,  90., 270.,
#         71., 125., 176.,  48.,  64., 228.,  76., 220.,  40., 152.,  18.,
#        135., 495.,  37.,  51.,  99., 145., 225.,  49.,  50.,  92., 325.,
#         63., 284., 119., 204., 155., 485.,  53., 114., 105., 285.,  78.,
#        130.,  55.,  58., 160., 210., 318.,  44., 190., 280.,  87., 271.,
#        129., 120., 478.,  56.,  32., 744., 370.,  45., 194., 680., 402.,
#        258., 375., 150.,  67.,  57., 116., 278., 122., 545.,  75.,  74.,
#        182., 360., 215., 184.,  42., 132., 148., 180., 205.,  85., 231.,
#         29.,  68.,  52., 255., 171.,  73., 108.,  43., 167., 249., 293.,
#         66., 465.,  89., 158.,  84.,  72.,  59.,  81., 196., 415., 275.,
#        165., 579., 310.,  61., 474., 170., 277.,  60.,  14.,  95., 237.,
# ...

# %%
diabetes_df['SkinThickness'].unique()
# Out:
# array([35., 29., nan, 23., 32., 45., 19., 47., 38., 30., 41., 33., 26.,
#        15., 36., 11., 31., 37., 42., 25., 18., 24., 39., 27., 21., 34.,
#        10., 60., 13., 20., 22., 28., 54., 40., 51., 56., 14., 17., 50.,
#        44., 12., 46., 16.,  7., 52., 43., 48.,  8., 49., 63., 99.])

# %%
val_insulin = np.round(diabetes_df['Insulin'].mean())

# %%
diabetes_df['Insulin'].replace(np.nan,val_insulin, inplace = True)

# %%
diabetes_df.isnull().sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                       0
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Pregnancies                   0
# Outcome                       0
# dtype: int64

# %%
val_SkinThickness = np.round(diabetes_df['SkinThickness'].median())

# %%
diabetes_df['SkinThickness'].replace(np.nan,val_SkinThickness, inplace = True)

# %%
diabetes_df.isnull().sum()
# Out:
# Glucose                      5
# BloodPressure               35
# SkinThickness                0
# Insulin                      0
# BMI                         11
# DiabetesPedigreeFunction     0
# Age                          0
# Pregnancies                  0
# Outcome                      0
# dtype: int64

# %%
diabetes_df['BloodPressure'].unique()
# Out:
# array([ 72.,  66.,  64.,  40.,  74.,  50.,  nan,  70.,  96.,  92.,  80.,
#         60.,  84.,  30.,  88.,  90.,  94.,  76.,  82.,  75.,  58.,  78.,
#         68., 110.,  56.,  62.,  85.,  86.,  48.,  44.,  65., 108.,  55.,
#        122.,  54.,  52.,  98., 104.,  95.,  46., 102., 100.,  61.,  24.,
#         38., 106., 114.])

# %% [markdown]
# **Impute**
#
# *   Missing Multiple Columns

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')

# %%
d_array = imputer.fit_transform(diabetes_df)

# %%
diabetes_df2 = pd.DataFrame( d_array, columns = diabetes_df.columns)

# %%
diabetes_df2
# Out:
#      Glucose  BloodPressure  SkinThickness  ...   Age  Pregnancies  Outcome
# 0      148.0           72.0           35.0  ...  50.0          6.0      1.0
# 1       85.0           66.0           29.0  ...  31.0          1.0      0.0
# 2      183.0           64.0           29.0  ...  32.0          8.0      1.0
# 3       89.0           66.0           23.0  ...  21.0          1.0      0.0
# 4      137.0           40.0           35.0  ...  33.0          0.0      1.0
# ..       ...            ...            ...  ...   ...          ...      ...
# 763    101.0           76.0           48.0  ...  63.0         10.0      0.0
# 764    122.0           70.0           27.0  ...  27.0          2.0      0.0
# 765    121.0           72.0           23.0  ...  30.0          5.0      0.0
# 766    126.0           60.0           29.0  ...  47.0          1.0      1.0
# 767     93.0           70.0           31.0  ...  23.0          1.0      0.0
#
# [768 rows x 9 columns]

# %%
#c axis = 1 dropping entire column 

diabetes_df2.drop(['Outcome'], axis = 1)
# Out:
#      Glucose  BloodPressure  ...   Age  Pregnancies
# 0      148.0           72.0  ...  50.0          6.0
# 1       85.0           66.0  ...  31.0          1.0
# 2      183.0           64.0  ...  32.0          8.0
# 3       89.0           66.0  ...  21.0          1.0
# 4      137.0           40.0  ...  33.0          0.0
# ..       ...            ...  ...   ...          ...
# 763    101.0           76.0  ...  63.0         10.0
# 764    122.0           70.0  ...  27.0          2.0
# 765    121.0           72.0  ...  30.0          5.0
# 766    126.0           60.0  ...  47.0          1.0
# 767     93.0           70.0  ...  23.0          1.0
#
# [768 rows x 8 columns]

# %%
# axis = 0 dropping entire rows

diabetes_df2.drop([0,1,2,3,4,5,6], axis = 0)
# Out:
#      Glucose  BloodPressure  SkinThickness  ...   Age  Pregnancies  Outcome
# 7      115.0           72.0           29.0  ...  29.0         10.0      0.0
# 8      197.0           70.0           45.0  ...  53.0          2.0      1.0
# 9      125.0           96.0           29.0  ...  54.0          8.0      1.0
# 10     110.0           92.0           29.0  ...  30.0          4.0      0.0
# 11     168.0           74.0           29.0  ...  34.0         10.0      1.0
# ..       ...            ...            ...  ...   ...          ...      ...
# 763    101.0           76.0           48.0  ...  63.0         10.0      0.0
# 764    122.0           70.0           27.0  ...  27.0          2.0      0.0
# 765    121.0           72.0           23.0  ...  30.0          5.0      0.0
# 766    126.0           60.0           29.0  ...  47.0          1.0      1.0
# 767     93.0           70.0           31.0  ...  23.0          1.0      0.0
#
# [761 rows x 9 columns]

# %%
diabetes_df2.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Pregnancies                 0
# Outcome                     0
# dtype: int64

# %%
titanic_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/Titanic_Data.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#cabin is nominal data

titanic_df.drop(['Cabin'], axis = 1, inplace = True)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,8))
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic_df)

# %%
def imputer_age(cols):
  Age = cols[0]
  Pclass = cols[1]

  if pd.isnull(Age) :
    if Pclass == 1:
      return 38
    elif Pclass == 2 :
      return 29
    else :
      return 24
    
  else :
    return Age

# %%
titanic_df['Age'] = titanic_df[['Age', 'Pclass']].apply(imputer_age, axis = 1)

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
titanic_df.dropna(inplace=True)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [889 rows x 11 columns]

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# **OutLiers**

# %%
# value of sample > Q3 + 1.5 * IQR
# Value of sample > Q1 - 1.5 * IQR

# %%
plt.figure(figsize = (20,8))
sns.boxplot(data = diabetes_df2)

# %%
 def find_outliers(input_df) :
  q1 = input_df.quantile(0.25)
  q3 = input_df.quantile(0.75)

  iqr = q3 - q1
  min_range = q1 - 1.5 * iqr
  max_range = q3 + 1.5 * iqr

  # indexes of outliers
  
  outliers_indices = list(input_df.index[(input_df < min_range) | (input_df > max_range)])
  outliers_values = list(input_df[outliers_indices])

  print(" min range : %i" %min_range)
  print(" max range : %i" %max_range)

  return outliers_indices, outliers_values

# %%
find_outliers(diabetes_df2['Age'])
# Out:
#  min range : -1
#  max range : 66
# ([123, 363, 453, 459, 489, 537, 666, 674, 684],
#  [69.0, 67.0, 72.0, 81.0, 67.0, 67.0, 70.0, 68.0, 69.0])

# %% [markdown]
# **Replacing Outliers With Mean or Median**

# %%
median_val = np.median(diabetes_df2['Age'])

# %%
median_val
# Out:
# 29.0

# %%
diabetes_df2['Age'] = np.where(diabetes_df2['Age'] > 66, median_val, diabetes_df2['Age'])

# %%
find_outliers(diabetes_df2['Age'])
# Out:
#  min range : 0
#  max range : 64
# ([148, 221, 294, 362, 495, 552, 759],
#  [65.0, 66.0, 65.0, 65.0, 66.0, 66.0, 66.0])

# %% [markdown]
# **Drop the Outliers**

# %%
#diabetes_df2.drop([148, 221, 294, 362, 495, 552, 759], inplace = True)

# %%
plt.figure(figsize = (20,8))
sns.boxplot(data = diabetes_df2)

# %%
#for i in diabetes_df2.columns:
#  print(i)
#  print(find_outliers(diabetes_df2[i]))

# %% [markdown]
# **Forward FILL**
#
#
#
# *   Replacing missing values with previous data of column

# %%
diabetes_df2.ffill()
# Out:
#      Glucose  BloodPressure  SkinThickness  ...   Age  Pregnancies  Outcome
# 0      148.0           72.0           35.0  ...  50.0          6.0      1.0
# 1       85.0           66.0           29.0  ...  31.0          1.0      0.0
# 2      183.0           64.0           29.0  ...  32.0          8.0      1.0
# 3       89.0           66.0           23.0  ...  21.0          1.0      0.0
# 4      137.0           40.0           35.0  ...  33.0          0.0      1.0
# ..       ...            ...            ...  ...   ...          ...      ...
# 763    101.0           76.0           48.0  ...  63.0         10.0      0.0
# 764    122.0           70.0           27.0  ...  27.0          2.0      0.0
# 765    121.0           72.0           23.0  ...  30.0          5.0      0.0
# 766    126.0           60.0           29.0  ...  47.0          1.0      1.0
# 767     93.0           70.0           31.0  ...  23.0          1.0      0.0
#
# [768 rows x 9 columns]

# %% [markdown]
# **SCALING**

# %%
x = diabetes_df2.drop(['Outcome'], axis=1)

# %% [markdown]
# **MinMaxScaler**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))
# Here 0 will be treated as min. value from dataset and similarly in case of 1 is treated as max.

scaler.fit(x)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.transform(x)
# Out:
# array([[0.67096774, 0.48979592, 0.30434783, ..., 0.23441503, 0.64444444,
#         0.35294118],
#        [0.26451613, 0.42857143, 0.23913043, ..., 0.11656704, 0.22222222,
#         0.05882353],
#        [0.89677419, 0.40816327, 0.23913043, ..., 0.25362938, 0.24444444,
#         0.47058824],
#        ...,
#        [0.49677419, 0.48979592, 0.17391304, ..., 0.07130658, 0.2       ,
#         0.29411765],
#        [0.52903226, 0.36734694, 0.23913043, ..., 0.11571307, 0.57777778,
#         0.05882353],
#        [0.31612903, 0.46938776, 0.26086957, ..., 0.10119556, 0.04444444,
#         0.05882353]])

# %% [markdown]
# **Standard Scaler**
#
# *   To nulify the impact of data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
data = [[0, 0], [0, 1], [1, 0], [1, 1]]
scaler.fit(data)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaler.transform(data)
# Out:
# array([[-1., -1.],
#        [-1.,  1.],
#        [ 1., -1.],
#        [ 1.,  1.]])

# %% [markdown]
# **Label Encoder**
#
#
#
# *   Can be implemented when we have two type of data type only in columns
# *   To convert Categorical form of data into discrete form of data
# *   Replaced Male/Female with 1 & 0

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [889 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
titanic_df['Sex'] = encoder.fit_transform(titanic_df['Sex'])

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [889 rows x 11 columns]

# %% [markdown]
# **One Hot Encoding**
#
#
# *   Can be used when there is only two division of data
# *   pd.get_dummies can also be used

# %%
titanic_df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
embarked = pd.get_dummies(titanic_df['Embarked'])

# %%
display(embarked)
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [889 rows x 3 columns]

# %%
#Concatenation of two dataframes

titanic = pd.concat([titanic_df, embarked], axis = 1)

# %%
display(titanic)
# Out:
#      PassengerId  Survived  Pclass  ...  C  Q  S
# 0              1         0       3  ...  0  0  1
# 1              2         1       1  ...  1  0  0
# 2              3         1       3  ...  0  0  1
# 3              4         1       1  ...  0  0  1
# 4              5         0       3  ...  0  0  1
# ..           ...       ...     ...  ... .. .. ..
# 886          887         0       2  ...  0  0  1
# 887          888         1       1  ...  0  0  1
# 888          889         0       3  ...  0  0  1
# 889          890         1       1  ...  1  0  0
# 890          891         0       3  ...  0  1  0
#
# [889 rows x 14 columns]

# %%
titanic.drop(['Embarked'], axis=1)
# Out:
#      PassengerId  Survived  Pclass  ...  C  Q  S
# 0              1         0       3  ...  0  0  1
# 1              2         1       1  ...  1  0  0
# 2              3         1       3  ...  0  0  1
# 3              4         1       1  ...  0  0  1
# 4              5         0       3  ...  0  0  1
# ..           ...       ...     ...  ... .. .. ..
# 886          887         0       2  ...  0  0  1
# 887          888         1       1  ...  0  0  1
# 888          889         0       3  ...  0  0  1
# 889          890         1       1  ...  1  0  0
# 890          891         0       3  ...  0  1  0
#
# [889 rows x 13 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

# %%
encoder.fit_transform([['Female', 0], ['Male', 1]]).toarray()
# Out:
# array([[1., 0., 1., 0.],
#        [0., 1., 0., 1.]])

# %% [markdown]
# Removing Outliers In Insulin

# %%
plt.figure(figsize = (20,8))
sns.boxplot(data = diabetes_df2)

# %%
find_outliers(diabetes_df2['Insulin'])
# Out:
#  min range : 69
#  max range : 207
# ([8,
#   13,
#   16,
#   20,
#   31,
#   32,
#   43,
#   51,
#   52,
#   53,
#   54,
#   56,
#   68,
#   73,
#   92,
#   94,
#   95,
#   98,
#   99,
#   103,
#   108,
#   109,
#   111,
#   112,
#   119,
#   132,
#   134,
#   136,
#   139,
#   142,
#   144,
#   153,
#   158,
#   162,
#   173,
#   174,
#   182,
#   186,
#   187,
#   195,
#   197,
#   199,
#   203,
#   206,
#   215,
#   220,
#   224,
#   225,
#   228,
#   229,
#   231,
#   232,
#   234,
#   247,
#   248,
#   252,
#   254,
#   258,
#   265,
#   271,
#   273,
#   275,
#   279,
#   286,
#   287,
#   288,
#   290,
#   296,
#   297,
#   302,
#   316,
#   320,
#   323,
#   329,
#   331,
#   334,
#   335,
#   353,
#   358,
#   359,
#   360,
#   364,
#   368,
#   370,
#   372,
#   375,
#   383,
#   385,
#   388,
#   392,
#   395,
#   409,
#   412,
#   413,
#   415,
#   424,
#   425,
#   432,
#   441,
#   445,
#   448,
#   449,
#   452,
#   458,
#   459,
#   460,
#   462,
#   466,
#   480,
# ...

# %%
median_val = np.median(diabetes_df2['Insulin'])

# %%
median_val
# Out:
# 156.0

# %%
diabetes_df2['Insulin'] = np.where(diabetes_df2['Insulin'] > 207, median_val, diabetes_df2['Insulin'])

# %%
find_outliers(diabetes_df2['Age'])
# Out:
#  min range : 0
#  max range : 64
# ([148, 221, 294, 362, 495, 552, 759],
#  [65.0, 66.0, 65.0, 65.0, 66.0, 66.0, 66.0])

# %%
#find_outliers(diabetes_df2['Insulin'])

# %%
#diabetes_df2.drop([], inplace = True)
